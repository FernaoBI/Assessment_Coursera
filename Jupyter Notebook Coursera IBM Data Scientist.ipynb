# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fernao Wouters**
# Current occupation: Business Intelligence Consultant

# %% [markdown]
# *I am interested in Data Science because during my masters study in Business Intelligence, Machine Learning and predictive models sparked a lot of interest. Now my goal is to build predictive models and implement machine learning in my current organisation.*

# %% [markdown]
# ### My code in Cell 5 will add the numbers 1 and 5 and print the result.

# %%
print(1 + 5)
# Out:
# 6

# %% [markdown]
# In this cell I include horizontal rule, bulleted list and a numbered list.
#
# Horizontal rule:
# ***
#
# Bulleted list:
# - Chicken
# - Cow
# - Pig
#
#
#
# Ordered list:
# 1. Cheese
# 2. Carrot
# 3. Coconut
